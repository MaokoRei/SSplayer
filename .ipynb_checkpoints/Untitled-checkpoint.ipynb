# %%
import pandas as pd
from attackCard import load_attack_cards_from_excel, AttackCard

file_path = "attackCard.xlsx"  # 如果是 attackCard.excel，请先改成 .xlsx
cards = load_attack_cards_from_excel(file_path)

# 查看前几张卡
for card in cards:
    print(card)
# Out:
# <AttackCard id=0 name=strike>
# <AttackCard id=1 name=bash>
# <AttackCard id=2 name=anger>
# <AttackCard id=3 name=bodySlam>
# <AttackCard id=4 name=breakthrough>
# <AttackCard id=5 name=headbutt>
# <AttackCard id=6 name=ironWave>
# <AttackCard id=7 name=moltenFirst>
# <AttackCard id=8 name=pommelStrike>
# <AttackCard id=9 name=setupStrike>
# <AttackCard id=10 name=swordBoomerang>
# <AttackCard id=11 name=thunderclap>
# <AttackCard id=12 name=twinStrike>
# <AttackCard id=13 name=cinder>
# <AttackCard id=14 name=perfectedStrike>
# <AttackCard id=15 name=bully>
# <AttackCard id=16 name=spite>
# <AttackCard id=17 name=whirlwind>
# <AttackCard id=18 name=ashenStrike>
# <AttackCard id=19 name=dismantle>
# <AttackCard id=20 name=grapple>
# <AttackCard id=21 name=hemokinesis>
# <AttackCard id=22 name=pillage>
# <AttackCard id=23 name=howlfrombeyond>
# <AttackCard id=24 name=stomp>
# <AttackCard id=25 name=pactsEnd>
# <AttackCard id=26 name=conflagration>
# <AttackCard id=27 name=feed>
# ...

# %%
player = Player(maxHP=80)

player.input_player_state()
# Out:
# === 输入玩家状态（直接回车表示不修改）===
# maxHP (当前: 80)：
# HP (当前: 80)： 79
# block (当前: 0)： 0
# strength (当前: 0)： 0
# vulnerable (当前: 0)： 0
# dexterity (当前: 0)： 0
# weak (当前: 0)： 0
# 更新完成： <Player HP=79/80,Block = 0 STR=0, DEX=0, VUL=0, WEAK=0>
